# %% [markdown]
# # Setup

# %%
### SETUP ###
# Data manipulation libraries
import sys
import pandas as pd
pd.set_option("display.max_columns", None)
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Path and OS libraries
from pathlib import Path
import sys
import os

# Repo root is parent of /notebooks
PROJECT_ROOT = Path.cwd().parent

# (Optional) confirm you found the right place
assert (PROJECT_ROOT / "README.md").exists(), "PROJECT_ROOT is wrong (README.md not found)."

DATA_RAW = PROJECT_ROOT / "data" / "raw"
DATA_PROCESSED = PROJECT_ROOT / "data" / "processed"
NOTEBOOKS = PROJECT_ROOT / "notebooks"
SRC = PROJECT_ROOT / "src"

# %%
# Environment Check
import sys
import os
print("Python:", sys.version)
print("Executable:", sys.executable)
# Out:
# Python: 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]
# Executable: c:\Users\nhame\anaconda3\envs\nico-env\python.exe

# %%
print("Project root:", PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
# Out:
# Project root: c:\Users\nhame\OneDrive\Documents\GitHub\biodiversity-in-national-parks
